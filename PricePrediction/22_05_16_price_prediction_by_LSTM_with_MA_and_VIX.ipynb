# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)

# %%
import yfinance as yf
from datetime import datetime
import pandas_datareader as pdr
import pandas as pd

# %%
final = datetime.today()

# %%
vix = yf.download('^VIX', interval='1d', start="2017-09-25", end=final)['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vix = pd.DataFrame(vix)
vix
# Out:
#                 Close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-10  32.990002
# 2022-05-11  32.560001
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  29.799999
#
# [1169 rows x 1 columns]

# %%
vix_close = vix.rename(columns={"Close": "vix_close"})
vix_close
# Out:
#             vix_close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-10  32.990002
# 2022-05-11  32.560001
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  29.799999
#
# [1169 rows x 1 columns]

# %%
# !pip install pyupbit
# Out:
# Requirement already satisfied: pyupbit in /usr/local/lib/python3.7/dist-packages (0.2.30)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyupbit) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pyupbit) (2.27.1)
# Requirement already satisfied: pyjwt>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pyupbit) (2.4.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.7/dist-packages (from pyupbit) (10.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyupbit) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2.10)

# %%
import time
import pyupbit
import datetime

# %%
access = "key"
secret = "key"

# %%
# 로그인
upbit = pyupbit.Upbit(access, secret)

# %% [markdown]
# # 2017-09-25 ~ 현재 -> 약 1690개

# %%
ticker = "KRW-BTC"
df = pyupbit.get_ohlcv(ticker, interval="day", count=3650)

# %%
df_org = df.copy()

# %%
df = df_org

# %%
df.head()
# Out:
#                                 open       high        low      close  \
# 2017-09-25 09:00:00+00:00  4201000.0  4333000.0  4175000.0  4322000.0
# 2017-09-26 09:00:00+00:00  4317000.0  4418000.0  4311000.0  4321000.0
# 2017-09-27 09:00:00+00:00  4322000.0  4677000.0  4318000.0  4657000.0
# 2017-09-28 09:00:00+00:00  4657000.0  4772000.0  4519000.0  4586000.0
# 2017-09-29 09:00:00+00:00  4586000.0  4709000.0  4476000.0  4657000.0
#
#                                volume         value
# 2017-09-25 09:00:00+00:00  132.484755  5.602146e+08
# 2017-09-26 09:00:00+00:00   22.788340  9.950724e+07
# 2017-09-27 09:00:00+00:00   32.269662  1.448276e+08
# 2017-09-28 09:00:00+00:00   80.588243  3.721860e+08
# 2017-09-29 09:00:00+00:00   59.352373  2.724558e+08

# %%
df.reset_index(inplace=True)
df
# Out:
#                          index        open        high         low  \
# 0    2017-09-25 09:00:00+00:00   4201000.0   4333000.0   4175000.0
# 1    2017-09-26 09:00:00+00:00   4317000.0   4418000.0   4311000.0
# 2    2017-09-27 09:00:00+00:00   4322000.0   4677000.0   4318000.0
# 3    2017-09-28 09:00:00+00:00   4657000.0   4772000.0   4519000.0
# 4    2017-09-29 09:00:00+00:00   4586000.0   4709000.0   4476000.0
# ...                        ...         ...         ...         ...
# 1690 2022-05-12 09:00:00+00:00  40263000.0  41178000.0  37000000.0
# 1691 2022-05-13 09:00:00+00:00  39246000.0  41324000.0  38777000.0
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  39000000.0
#
#            close        volume         value
# 0      4322000.0    132.484755  5.602146e+08
# 1      4321000.0     22.788340  9.950724e+07
# 2      4657000.0     32.269662  1.448276e+08
# 3      4586000.0     80.588243  3.721860e+08
# 4      4657000.0     59.352373  2.724558e+08
# ...          ...           ...           ...
# 1690  39243000.0  23389.063427  9.115180e+11
# 1691  39270000.0  12398.918801  4.983739e+11
# 1692  39967000.0   5512.195620  2.170088e+11
# 1693  40906000.0   4277.655034  1.706726e+11
# 1694  39454000.0   2602.010378  1.035034e+11
#
# [1695 rows x 7 columns]

# %%
df = df.rename(columns={"index": "Date"})
df
# Out:
#                           Date        open        high         low  \
# 0    2017-09-25 09:00:00+00:00   4201000.0   4333000.0   4175000.0
# 1    2017-09-26 09:00:00+00:00   4317000.0   4418000.0   4311000.0
# 2    2017-09-27 09:00:00+00:00   4322000.0   4677000.0   4318000.0
# 3    2017-09-28 09:00:00+00:00   4657000.0   4772000.0   4519000.0
# 4    2017-09-29 09:00:00+00:00   4586000.0   4709000.0   4476000.0
# ...                        ...         ...         ...         ...
# 1690 2022-05-12 09:00:00+00:00  40263000.0  41178000.0  37000000.0
# 1691 2022-05-13 09:00:00+00:00  39246000.0  41324000.0  38777000.0
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  39000000.0
#
#            close        volume         value
# 0      4322000.0    132.484755  5.602146e+08
# 1      4321000.0     22.788340  9.950724e+07
# 2      4657000.0     32.269662  1.448276e+08
# 3      4586000.0     80.588243  3.721860e+08
# 4      4657000.0     59.352373  2.724558e+08
# ...          ...           ...           ...
# 1690  39243000.0  23389.063427  9.115180e+11
# 1691  39270000.0  12398.918801  4.983739e+11
# 1692  39967000.0   5512.195620  2.170088e+11
# 1693  40906000.0   4277.655034  1.706726e+11
# 1694  39454000.0   2602.010378  1.035034e+11
#
# [1695 rows x 7 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"].dt.date)
df
# Out:
#            Date        open        high         low       close        volume  \
# 0    2017-09-25   4201000.0   4333000.0   4175000.0   4322000.0    132.484755
# 1    2017-09-26   4317000.0   4418000.0   4311000.0   4321000.0     22.788340
# 2    2017-09-27   4322000.0   4677000.0   4318000.0   4657000.0     32.269662
# 3    2017-09-28   4657000.0   4772000.0   4519000.0   4586000.0     80.588243
# 4    2017-09-29   4586000.0   4709000.0   4476000.0   4657000.0     59.352373
# ...         ...         ...         ...         ...         ...           ...
# 1690 2022-05-12  40263000.0  41178000.0  37000000.0  39243000.0  23389.063427
# 1691 2022-05-13  39246000.0  41324000.0  38777000.0  39270000.0  12398.918801
# 1692 2022-05-14  39270000.0  40243000.0  38400000.0  39967000.0   5512.195620
# 1693 2022-05-15  39967000.0  41000000.0  39270000.0  40906000.0   4277.655034
# 1694 2022-05-16  40902000.0  40940000.0  39000000.0  39454000.0   2602.010378
#
#              value
# 0     5.602146e+08
# 1     9.950724e+07
# 2     1.448276e+08
# 3     3.721860e+08
# 4     2.724558e+08
# ...            ...
# 1690  9.115180e+11
# 1691  4.983739e+11
# 1692  2.170088e+11
# 1693  1.706726e+11
# 1694  1.035034e+11
#
# [1695 rows x 7 columns]

# %%
vix_close[["vix_close"]]
# Out:
#             vix_close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-10  32.990002
# 2022-05-11  32.560001
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  29.799999
#
# [1169 rows x 1 columns]

# %%
df = pd.merge(df, vix_close, on="Date", how="left")
df.head(20)
# Out:
#          Date       open       high        low      close      volume  \
# 0  2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1  2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2  2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3  2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4  2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
# 5  2017-09-30  4657000.0  4896000.0  4651000.0  4895000.0   19.998483
# 6  2017-10-01  4889000.0  4978000.0  4682000.0  4962000.0   27.323332
# 7  2017-10-02  4962000.0  5095000.0  4956000.0  5025000.0   31.728004
# 8  2017-10-03  5021000.0  5079000.0  4811000.0  4964000.0   11.899307
# 9  2017-10-04  4987000.0  5002000.0  4837000.0  4895000.0    7.038744
# 10 2017-10-05  4894000.0  4993000.0  4811000.0  4926000.0    5.363652
# 11 2017-10-06  4927000.0  5034000.0  4885000.0  5027000.0   25.163820
# 12 2017-10-07  4983000.0  5070000.0  4935000.0  5047000.0    4.343932
# 13 2017-10-08  5044000.0  5263000.0  4993000.0  5217000.0  145.917860
# 14 2017-10-09  5222000.0  5761000.0  5188000.0  5477000.0    8.070434
# 15 2017-10-10  5469000.0  5665000.0  5459000.0  5486000.0   11.693694
# 16 2017-10-11  5533000.0  5605000.0  5451000.0  5557000.0    4.212650
# 17 2017-10-12  5569000.0  6377000.0  5515000.0  6332000.0   20.918287
# 18 2017-10-13  6346000.0  6950000.0  6149000.0  6438000.0   26.826084
# 19 2017-10-14  6427000.0  6664000.0  6322000.0  6664000.0    3.352825
#
#            value  vix_close
# 0   5.602146e+08      10.21
# 1   9.950724e+07      10.17
# 2   1.448276e+08       9.87
# 3   3.721860e+08       9.55
# 4   2.724558e+08       9.51
# 5   9.561476e+07        NaN
# 6   1.331325e+08        NaN
# 7   1.599315e+08       9.45
# 8   5.890130e+07       9.51
# 9   3.458813e+07       9.63
# 10  2.637132e+07       9.19
# 11  1.239351e+08       9.65
# 12  2.166749e+07        NaN
# 13  7.382940e+08        NaN
# 14  4.327059e+07      10.33
# 15  6.482276e+07      10.08
# 16  2.332489e+07       9.85
# 17  1.189924e+08       9.91
# 18  1.752832e+08       9.61
# 19  2.171336e+07        NaN

# %%
df = join_data.fillna(method = "ffill")
df.head(20)
# Out:
#          Date       open       high        low      close      volume  \
# 0  2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1  2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2  2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3  2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4  2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
# 5  2017-09-30  4657000.0  4896000.0  4651000.0  4895000.0   19.998483
# 6  2017-10-01  4889000.0  4978000.0  4682000.0  4962000.0   27.323332
# 7  2017-10-02  4962000.0  5095000.0  4956000.0  5025000.0   31.728004
# 8  2017-10-03  5021000.0  5079000.0  4811000.0  4964000.0   11.899307
# 9  2017-10-04  4987000.0  5002000.0  4837000.0  4895000.0    7.038744
# 10 2017-10-05  4894000.0  4993000.0  4811000.0  4926000.0    5.363652
# 11 2017-10-06  4927000.0  5034000.0  4885000.0  5027000.0   25.163820
# 12 2017-10-07  4983000.0  5070000.0  4935000.0  5047000.0    4.343932
# 13 2017-10-08  5044000.0  5263000.0  4993000.0  5217000.0  145.917860
# 14 2017-10-09  5222000.0  5761000.0  5188000.0  5477000.0    8.070434
# 15 2017-10-10  5469000.0  5665000.0  5459000.0  5486000.0   11.693694
# 16 2017-10-11  5533000.0  5605000.0  5451000.0  5557000.0    4.212650
# 17 2017-10-12  5569000.0  6377000.0  5515000.0  6332000.0   20.918287
# 18 2017-10-13  6346000.0  6950000.0  6149000.0  6438000.0   26.826084
# 19 2017-10-14  6427000.0  6664000.0  6322000.0  6664000.0    3.352825
#
#            value  vix_close
# 0   5.602146e+08      10.21
# 1   9.950724e+07      10.17
# 2   1.448276e+08       9.87
# 3   3.721860e+08       9.55
# 4   2.724558e+08       9.51
# 5   9.561476e+07       9.51
# 6   1.331325e+08       9.51
# 7   1.599315e+08       9.45
# 8   5.890130e+07       9.51
# 9   3.458813e+07       9.63
# 10  2.637132e+07       9.19
# 11  1.239351e+08       9.65
# 12  2.166749e+07       9.65
# 13  7.382940e+08       9.65
# 14  4.327059e+07      10.33
# 15  6.482276e+07      10.08
# 16  2.332489e+07       9.85
# 17  1.189924e+08       9.91
# 18  1.752832e+08       9.61
# 19  2.171336e+07       9.61

# %% [markdown]
# # stationary(price) -> non-stationary(price_diff)

# %%
df["open_diff"] = df["open"] - df["open"].shift(1)
df["high_diff"] = df["high"] - df["high"].shift(1)
df["low_diff"] = df["low"] - df["low"].shift(1)
df["close_diff"] = df["close"] - df["close"].shift(1)

# %%
df.head()
# Out:
#         Date       open       high        low      close      volume  \
# 0 2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1 2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2 2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3 2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4 2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
#
#           value  vix_close  open_diff  high_diff  low_diff  close_diff
# 0  5.602146e+08      10.21        NaN        NaN       NaN         NaN
# 1  9.950724e+07      10.17   116000.0    85000.0  136000.0     -1000.0
# 2  1.448276e+08       9.87     5000.0   259000.0    7000.0    336000.0
# 3  3.721860e+08       9.55   335000.0    95000.0  201000.0    -71000.0
# 4  2.724558e+08       9.51   -71000.0   -63000.0  -43000.0     71000.0

# %%
df2 = df[["open_diff", "high_diff", "low_diff", "close_diff", "volume", "close", "vix_close"]]
df2.head()
# Out:
#    open_diff  high_diff  low_diff  close_diff      volume      close  \
# 0        NaN        NaN       NaN         NaN  132.484755  4322000.0
# 1   116000.0    85000.0  136000.0     -1000.0   22.788340  4321000.0
# 2     5000.0   259000.0    7000.0    336000.0   32.269662  4657000.0
# 3   335000.0    95000.0  201000.0    -71000.0   80.588243  4586000.0
# 4   -71000.0   -63000.0  -43000.0     71000.0   59.352373  4657000.0
#
#    vix_close
# 0      10.21
# 1      10.17
# 2       9.87
# 3       9.55
# 4       9.51

# %% [markdown]
# # Smoothing by Moving Average

# %% [markdown]
# 이동평균선 plot

# %%
df2["close"].plot(figsize=(15, 8))
df2["close"].rolling(window=30).mean().plot() # 30일 이동평균선

# %%
df2["close_MA30"] = df2["close"].rolling(window=30).mean()
df2.head()
# Out:
#    open_diff  high_diff  low_diff  close_diff      volume      close  \
# 0        NaN        NaN       NaN         NaN  132.484755  4322000.0
# 1   116000.0    85000.0  136000.0     -1000.0   22.788340  4321000.0
# 2     5000.0   259000.0    7000.0    336000.0   32.269662  4657000.0
# 3   335000.0    95000.0  201000.0    -71000.0   80.588243  4586000.0
# 4   -71000.0   -63000.0  -43000.0     71000.0   59.352373  4657000.0
#
#    vix_close  close_MA30
# 0      10.21         NaN
# 1      10.17         NaN
# 2       9.87         NaN
# 3       9.55         NaN
# 4       9.51         NaN

# %%
df2["close_diff_ma5"] = df2["close_diff"].rolling(window=5).mean()
df2["close_diff_ma10"] = df2["close_diff"].rolling(window=10).mean()
df2["close_diff_ma20"] = df2["close_diff"].rolling(window=20).mean()
df2["close_diff_ma60"] = df2["close_diff"].rolling(window=60).mean()
df2["close_diff_ma120"] = df2["close_diff"].rolling(window=120).mean()

# %%
df = df2[["close_diff_ma5", "close_diff_ma10", "close_diff_ma20", "close_diff_ma60", "close_diff_ma120", "close", "vix_close"]]
df
# Out:
#       close_diff_ma5  close_diff_ma10  close_diff_ma20  close_diff_ma60  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
# ...              ...              ...              ...              ...
# 1690      -1452800.0       -1027700.0        -534700.0   -137783.333333
# 1691      -1100000.0        -950700.0        -523600.0   -165016.666667
# 1692       -207000.0       -1064900.0        -482650.0   -144550.000000
# 1693        -28000.0        -674100.0        -485400.0   -158050.000000
# 1694       -208000.0        -778100.0        -476350.0   -180316.666667
#
#       close_diff_ma120       close  vix_close
# 0                  NaN   4322000.0  10.210000
# 1                  NaN   4321000.0  10.170000
# 2                  NaN   4657000.0   9.870000
# 3                  NaN   4586000.0   9.550000
# 4                  NaN   4657000.0   9.510000
# ...                ...         ...        ...
# 1690    -117550.000000  39243000.0  31.770000
# 1691    -105125.000000  39270000.0  28.870001
# 1692    -102191.666667  39967000.0  28.870001
# 1693     -95425.000000  40906000.0  28.870001
# 1694    -107625.000000  39250000.0  28.870001
#
# [1695 rows x 7 columns]

# %% [markdown]
# # 1691 - 120 = 1571

# %%
df = df.dropna()
df_drop = df
df.head()
# Out:
#      close_diff_ma5  close_diff_ma10  close_diff_ma20  close_diff_ma60  \
# 120       -347800.0        -799400.0        -387950.0     65766.666667
# 121       -384400.0        -575600.0        -497600.0     59516.666667
# 122       -777000.0        -613300.0        -723550.0     43816.666667
# 123       -352800.0        -140300.0        -702400.0     26033.333333
# 124       -208800.0        -205100.0        -647950.0     14200.000000
#
#      close_diff_ma120       close  vix_close
# 120      73491.666667  13141000.0      11.10
# 121      76075.000000  13450000.0      11.47
# 122      69300.000000  12973000.0      11.58
# 123      69083.333333  12876000.0      11.08
# 124      68691.666667  12900000.0      11.08

# %%
len(df)
# Out:
# 1575

# %%
df[["close_diff_ma5", "close_diff_ma10", "close_diff_ma20", "close_diff_ma60", "close_diff_ma120", "vix_close"]].plot.line()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# %%
# inverse transform
def restore(row):
  return row * (max(df_drop["close"]) - min(df_drop["close"])) + min(df_drop["close"])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ["close_diff_ma5", "close_diff_ma10", "close_diff_ma20", "close_diff_ma60", "close_diff_ma120", "close", "vix_close"]
# 스케일 후 columns
scaled = scaler.fit_transform(df[scale_cols])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('close', 1), df['close'], test_size=0.2, random_state=0, shuffle=False)

# %% [markdown]
# # train set 80% -> 1571 * 0.8 = 1256.8 -> 1256 data

# %%
x_train.shape, y_train.shape
# Out:
# ((1260, 6), (1260,))

# %% [markdown]
# # test set 20% -> 1571 * 0.2 = 314.2 -> 315 data

# %%
x_test.shape, y_test.shape
# Out:
# ((315, 6), (315,))

# %%
x_train.tail()
# Out:
#       close_diff_ma5  close_diff_ma10  close_diff_ma20  close_diff_ma60  \
# 1255        0.661924         0.609175         0.424170         0.129865
# 1256        0.586609         0.602066         0.465652         0.111714
# 1257        0.616378         0.590545         0.422973         0.163078
# 1258        0.585362         0.580715         0.403777         0.147748
# 1259        0.565538         0.620458         0.380693         0.128218
#
#       close_diff_ma120  vix_close
# 1255          0.162268   0.064449
# 1256          0.179673   0.058742
# 1257          0.186393   0.058742
# 1258          0.197910   0.058742
# 1259          0.161884   0.058742

# %%
y_train.tail()
# Out:
# 1255    0.458976
# 1256    0.460545
# 1257    0.471562
# 1258    0.479906
# 1259    0.461367
# Name: close, dtype: float64

# %%
len(y_train)
# Out:
# 1260

# %%
x_test.tail()
# Out:
#       close_diff_ma5  close_diff_ma10  close_diff_ma20  close_diff_ma60  \
# 1570        0.360023         0.286684         0.314548         0.396194
# 1571        0.419493         0.307032         0.318401         0.375337
# 1572        0.570022         0.276854         0.332616         0.391011
# 1573        0.600196         0.380123         0.331661         0.380672
# 1574        0.569854         0.352641         0.334803         0.363619
#
#       close_diff_ma120  vix_close
# 1570          0.210421   0.291203
# 1571          0.226351   0.250835
# 1572          0.230112   0.250835
# 1573          0.238787   0.250835
# 1574          0.223146   0.250835

# %%
y_test.tail()
# Out:
# 1570    0.457986
# 1571    0.458333
# 1572    0.467294
# 1573    0.479366
# 1574    0.458076
# Name: close, dtype: float64

# %%
len(y_test)
# Out:
# 315

# %%
df2 = df_org
df2.tail()
# Out:
#                          index        open        high         low  \
# 1690 2022-05-12 09:00:00+00:00  40263000.0  41178000.0  37000000.0
# 1691 2022-05-13 09:00:00+00:00  39246000.0  41324000.0  38777000.0
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  39000000.0
#
#            close        volume         value
# 1690  39243000.0  23389.063427  9.115180e+11
# 1691  39270000.0  12398.918801  4.983739e+11
# 1692  39967000.0   5512.195620  2.170088e+11
# 1693  40906000.0   4277.655034  1.706726e+11
# 1694  39454000.0   2602.010378  1.035034e+11

# %% [markdown]
# TensorFlow Dataset을 활용한 시퀀스 데이터셋 구성

# %%
import tensorflow as tf

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
# 아래의 코드로 데이터셋의 구성을 확인해 볼 수 있습니다.
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(16, activation='tanh'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
#      35/Unknown - 3s 12ms/step - loss: 0.0248 - mse: 0.0496
# Epoch 1: val_loss improved from inf to 0.06848, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 3s 29ms/step - loss: 0.0233 - mse: 0.0466 - val_loss: 0.0685 - val_mse: 0.1370
# Epoch 2/50
# 35/39 [=========================>....] - ETA: 0s - loss: 0.0048 - mse: 0.0096
# Epoch 2: val_loss improved from 0.06848 to 0.00210, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0088 - val_loss: 0.0021 - val_mse: 0.0042
# Epoch 3/50
# 38/39 [============================>.] - ETA: 0s - loss: 6.6446e-04 - mse: 0.0013
# Epoch 3: val_loss improved from 0.00210 to 0.00188, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 6.6114e-04 - mse: 0.0013 - val_loss: 0.0019 - val_mse: 0.0038
# Epoch 4/50
# 38/39 [============================>.] - ETA: 0s - loss: 5.4817e-04 - mse: 0.0011
# Epoch 4: val_loss improved from 0.00188 to 0.00175, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 5.6398e-04 - mse: 0.0011 - val_loss: 0.0017 - val_mse: 0.0035
# Epoch 5/50
# 39/39 [==============================] - ETA: 0s - loss: 5.3404e-04 - mse: 0.0011
# Epoch 5: val_loss improved from 0.00175 to 0.00161, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 5.3404e-04 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 6/50
# 38/39 [============================>.] - ETA: 0s - loss: 5.0203e-04 - mse: 0.0010
# Epoch 6: val_loss did not improve from 0.00161
# 39/39 [==============================] - 1s 14ms/step - loss: 5.2354e-04 - mse: 0.0010 - val_loss: 0.0016 - val_mse: 0.0032
# Epoch 7/50
# 35/39 [=========================>....] - ETA: 0s - loss: 5.0420e-04 - mse: 0.0010
# Epoch 7: val_loss improved from 0.00161 to 0.00149, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 14ms/step - loss: 4.9447e-04 - mse: 9.8893e-04 - val_loss: 0.0015 - val_mse: 0.0030
# Epoch 8/50
# 35/39 [=========================>....] - ETA: 0s - loss: 4.8377e-04 - mse: 9.6754e-04
# Epoch 8: val_loss improved from 0.00149 to 0.00146, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 14ms/step - loss: 4.8156e-04 - mse: 9.6312e-04 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 9/50
# 38/39 [============================>.] - ETA: 0s - loss: 4.8250e-04 - mse: 9.6501e-04
# Epoch 9: val_loss improved from 0.00146 to 0.00135, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 17ms/step - loss: 4.8101e-04 - mse: 9.6201e-04 - val_loss: 0.0014 - val_mse: 0.0027
# Epoch 10/50
# 38/39 [============================>.] - ETA: 0s - loss: 4.6714e-04 - mse: 9.3429e-04
# Epoch 10: val_loss improved from 0.00135 to 0.00129, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 4.7190e-04 - mse: 9.4380e-04 - val_loss: 0.0013 - val_mse: 0.0026
# Epoch 11/50
# 35/39 [=========================>....] - ETA: 0s - loss: 4.2027e-04 - mse: 8.4054e-04
# Epoch 11: val_loss did not improve from 0.00129
# 39/39 [==============================] - 1s 14ms/step - loss: 4.2394e-04 - mse: 8.4788e-04 - val_loss: 0.0016 - val_mse: 0.0031
# Epoch 12/50
# 38/39 [============================>.] - ETA: 0s - loss: 4.4433e-04 - mse: 8.8866e-04
# Epoch 12: val_loss improved from 0.00129 to 0.00115, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 4.3802e-04 - mse: 8.7605e-04 - val_loss: 0.0011 - val_mse: 0.0023
# Epoch 13/50
# 35/39 [=========================>....] - ETA: 0s - loss: 4.0286e-04 - mse: 8.0572e-04
# Epoch 13: val_loss did not improve from 0.00115
# 39/39 [==============================] - 1s 16ms/step - loss: 3.9893e-04 - mse: 7.9785e-04 - val_loss: 0.0012 - val_mse: 0.0023
# Epoch 14/50
# 38/39 [============================>.] - ETA: 0s - loss: 3.8205e-04 - mse: 7.6411e-04
# Epoch 14: val_loss improved from 0.00115 to 0.00101, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 3.7560e-04 - mse: 7.5120e-04 - val_loss: 0.0010 - val_mse: 0.0020
# Epoch 15/50
# 39/39 [==============================] - ETA: 0s - loss: 3.4765e-04 - mse: 6.9530e-04
# Epoch 15: val_loss improved from 0.00101 to 0.00094, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 17ms/step - loss: 3.4765e-04 - mse: 6.9530e-04 - val_loss: 9.4140e-04 - val_mse: 0.0019
# Epoch 16/50
# 39/39 [==============================] - ETA: 0s - loss: 3.3812e-04 - mse: 6.7623e-04
# Epoch 16: val_loss improved from 0.00094 to 0.00091, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 3.3812e-04 - mse: 6.7623e-04 - val_loss: 9.0736e-04 - val_mse: 0.0018
# Epoch 17/50
# 39/39 [==============================] - ETA: 0s - loss: 3.1757e-04 - mse: 6.3514e-04
# Epoch 17: val_loss did not improve from 0.00091
# 39/39 [==============================] - 1s 16ms/step - loss: 3.1757e-04 - mse: 6.3514e-04 - val_loss: 9.4872e-04 - val_mse: 0.0019
# Epoch 18/50
# 35/39 [=========================>....] - ETA: 0s - loss: 2.8037e-04 - mse: 5.6074e-04
# Epoch 18: val_loss improved from 0.00091 to 0.00081, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.9403e-04 - mse: 5.8805e-04 - val_loss: 8.0752e-04 - val_mse: 0.0016
# Epoch 19/50
# 39/39 [==============================] - ETA: 0s - loss: 2.9970e-04 - mse: 5.9940e-04
# Epoch 19: val_loss improved from 0.00081 to 0.00075, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.9970e-04 - mse: 5.9940e-04 - val_loss: 7.4712e-04 - val_mse: 0.0015
# Epoch 20/50
# 35/39 [=========================>....] - ETA: 0s - loss: 3.5461e-04 - mse: 7.0922e-04
# Epoch 20: val_loss did not improve from 0.00075
# 39/39 [==============================] - 1s 14ms/step - loss: 3.4630e-04 - mse: 6.9260e-04 - val_loss: 9.5349e-04 - val_mse: 0.0019
# Epoch 21/50
# 34/39 [=========================>....] - ETA: 0s - loss: 3.0443e-04 - mse: 6.0886e-04
# Epoch 21: val_loss did not improve from 0.00075
# 39/39 [==============================] - 1s 14ms/step - loss: 2.9342e-04 - mse: 5.8684e-04 - val_loss: 7.7198e-04 - val_mse: 0.0015
# Epoch 22/50
# 35/39 [=========================>....] - ETA: 0s - loss: 2.6155e-04 - mse: 5.2310e-04
# Epoch 22: val_loss did not improve from 0.00075
# 39/39 [==============================] - 1s 14ms/step - loss: 2.5888e-04 - mse: 5.1776e-04 - val_loss: 7.5533e-04 - val_mse: 0.0015
# Epoch 23/50
# 39/39 [==============================] - ETA: 0s - loss: 2.6410e-04 - mse: 5.2820e-04
# Epoch 23: val_loss improved from 0.00075 to 0.00066, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.6410e-04 - mse: 5.2820e-04 - val_loss: 6.6257e-04 - val_mse: 0.0013
# Epoch 24/50
# 35/39 [=========================>....] - ETA: 0s - loss: 2.5374e-04 - mse: 5.0747e-04
# Epoch 24: val_loss improved from 0.00066 to 0.00064, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 16ms/step - loss: 2.4482e-04 - mse: 4.8963e-04 - val_loss: 6.4444e-04 - val_mse: 0.0013
# Epoch 25/50
# 35/39 [=========================>....] - ETA: 0s - loss: 2.4238e-04 - mse: 4.8477e-04
# Epoch 25: val_loss did not improve from 0.00064
# 39/39 [==============================] - 1s 14ms/step - loss: 2.4559e-04 - mse: 4.9118e-04 - val_loss: 7.6186e-04 - val_mse: 0.0015
# Epoch 26/50
# 38/39 [============================>.] - ETA: 0s - loss: 2.4875e-04 - mse: 4.9751e-04
# Epoch 26: val_loss did not improve from 0.00064
# 39/39 [==============================] - 1s 14ms/step - loss: 2.4707e-04 - mse: 4.9414e-04 - val_loss: 7.6887e-04 - val_mse: 0.0015
# Epoch 27/50
# 38/39 [============================>.] - ETA: 0s - loss: 2.3346e-04 - mse: 4.6693e-04
# Epoch 27: val_loss improved from 0.00064 to 0.00060, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.2969e-04 - mse: 4.5939e-04 - val_loss: 6.0362e-04 - val_mse: 0.0012
# Epoch 28/50
# 38/39 [============================>.] - ETA: 0s - loss: 2.2412e-04 - mse: 4.4824e-04
# Epoch 28: val_loss improved from 0.00060 to 0.00059, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.2251e-04 - mse: 4.4502e-04 - val_loss: 5.8804e-04 - val_mse: 0.0012
# Epoch 29/50
# 35/39 [=========================>....] - ETA: 0s - loss: 2.3364e-04 - mse: 4.6728e-04
# Epoch 29: val_loss improved from 0.00059 to 0.00058, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.3191e-04 - mse: 4.6383e-04 - val_loss: 5.7692e-04 - val_mse: 0.0012
# Epoch 30/50
# 39/39 [==============================] - ETA: 0s - loss: 2.5222e-04 - mse: 5.0443e-04
# Epoch 30: val_loss did not improve from 0.00058
# 39/39 [==============================] - 1s 17ms/step - loss: 2.5222e-04 - mse: 5.0443e-04 - val_loss: 9.2207e-04 - val_mse: 0.0018
# Epoch 31/50
# 39/39 [==============================] - ETA: 0s - loss: 2.1608e-04 - mse: 4.3216e-04
# Epoch 31: val_loss did not improve from 0.00058
# 39/39 [==============================] - 1s 16ms/step - loss: 2.1608e-04 - mse: 4.3216e-04 - val_loss: 7.2399e-04 - val_mse: 0.0014
# Epoch 32/50
# 39/39 [==============================] - ETA: 0s - loss: 2.1176e-04 - mse: 4.2352e-04
# Epoch 32: val_loss improved from 0.00058 to 0.00056, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.1176e-04 - mse: 4.2352e-04 - val_loss: 5.5518e-04 - val_mse: 0.0011
# Epoch 33/50
# 37/39 [===========================>..] - ETA: 0s - loss: 2.0604e-04 - mse: 4.1207e-04
# Epoch 33: val_loss improved from 0.00056 to 0.00055, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.0191e-04 - mse: 4.0382e-04 - val_loss: 5.5276e-04 - val_mse: 0.0011
# Epoch 34/50
# 37/39 [===========================>..] - ETA: 0s - loss: 2.4020e-04 - mse: 4.8039e-04
# Epoch 34: val_loss improved from 0.00055 to 0.00054, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.3432e-04 - mse: 4.6865e-04 - val_loss: 5.4291e-04 - val_mse: 0.0011
# Epoch 35/50
# 39/39 [==============================] - ETA: 0s - loss: 2.1096e-04 - mse: 4.2192e-04
# Epoch 35: val_loss improved from 0.00054 to 0.00053, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 2.1096e-04 - mse: 4.2192e-04 - val_loss: 5.3310e-04 - val_mse: 0.0011
# Epoch 36/50
# 39/39 [==============================] - ETA: 0s - loss: 2.0147e-04 - mse: 4.0294e-04
# Epoch 36: val_loss did not improve from 0.00053
# 39/39 [==============================] - 1s 17ms/step - loss: 2.0147e-04 - mse: 4.0294e-04 - val_loss: 5.9074e-04 - val_mse: 0.0012
# Epoch 37/50
# 39/39 [==============================] - ETA: 0s - loss: 1.9165e-04 - mse: 3.8330e-04
# Epoch 37: val_loss improved from 0.00053 to 0.00051, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 15ms/step - loss: 1.9165e-04 - mse: 3.8330e-04 - val_loss: 5.0772e-04 - val_mse: 0.0010
# Epoch 38/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.8555e-04 - mse: 3.7109e-04
# Epoch 38: val_loss did not improve from 0.00051
# 39/39 [==============================] - 1s 15ms/step - loss: 1.8541e-04 - mse: 3.7081e-04 - val_loss: 5.1788e-04 - val_mse: 0.0010
# Epoch 39/50
# 39/39 [==============================] - ETA: 0s - loss: 1.8472e-04 - mse: 3.6943e-04
# Epoch 39: val_loss did not improve from 0.00051
# 39/39 [==============================] - 1s 14ms/step - loss: 1.8472e-04 - mse: 3.6943e-04 - val_loss: 5.2846e-04 - val_mse: 0.0011
# Epoch 40/50
# 39/39 [==============================] - ETA: 0s - loss: 1.8066e-04 - mse: 3.6132e-04
# Epoch 40: val_loss did not improve from 0.00051
# 39/39 [==============================] - 1s 15ms/step - loss: 1.8066e-04 - mse: 3.6132e-04 - val_loss: 0.0012 - val_mse: 0.0023
# Epoch 41/50
# 39/39 [==============================] - ETA: 0s - loss: 1.9329e-04 - mse: 3.8659e-04
# Epoch 41: val_loss did not improve from 0.00051
# 39/39 [==============================] - 1s 14ms/step - loss: 1.9329e-04 - mse: 3.8659e-04 - val_loss: 5.1968e-04 - val_mse: 0.0010
# Epoch 42/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.7715e-04 - mse: 3.5431e-04
# Epoch 42: val_loss did not improve from 0.00051
# 39/39 [==============================] - 1s 14ms/step - loss: 1.7972e-04 - mse: 3.5945e-04 - val_loss: 8.3781e-04 - val_mse: 0.0017
# Epoch 43/50
# 39/39 [==============================] - ETA: 0s - loss: 1.7193e-04 - mse: 3.4385e-04
# Epoch 43: val_loss improved from 0.00051 to 0.00051, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 18ms/step - loss: 1.7193e-04 - mse: 3.4385e-04 - val_loss: 5.0590e-04 - val_mse: 0.0010
# Epoch 44/50
# 35/39 [=========================>....] - ETA: 0s - loss: 1.8575e-04 - mse: 3.7150e-04
# Epoch 44: val_loss improved from 0.00051 to 0.00046, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 17ms/step - loss: 1.8143e-04 - mse: 3.6285e-04 - val_loss: 4.6478e-04 - val_mse: 9.2957e-04
# Epoch 45/50
# 35/39 [=========================>....] - ETA: 0s - loss: 1.6866e-04 - mse: 3.3733e-04
# Epoch 45: val_loss did not improve from 0.00046
# 39/39 [==============================] - 1s 14ms/step - loss: 1.6667e-04 - mse: 3.3333e-04 - val_loss: 6.7634e-04 - val_mse: 0.0014
# Epoch 46/50
# 35/39 [=========================>....] - ETA: 0s - loss: 1.5941e-04 - mse: 3.1882e-04
# Epoch 46: val_loss did not improve from 0.00046
# 39/39 [==============================] - 1s 14ms/step - loss: 1.6354e-04 - mse: 3.2708e-04 - val_loss: 5.1031e-04 - val_mse: 0.0010
# Epoch 47/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.8211e-04 - mse: 3.6423e-04
# Epoch 47: val_loss did not improve from 0.00046
# 39/39 [==============================] - 1s 15ms/step - loss: 1.8133e-04 - mse: 3.6266e-04 - val_loss: 4.8781e-04 - val_mse: 9.7562e-04
# Epoch 48/50
# 35/39 [=========================>....] - ETA: 0s - loss: 1.7589e-04 - mse: 3.5179e-04
# Epoch 48: val_loss did not improve from 0.00046
# 39/39 [==============================] - 1s 14ms/step - loss: 1.7652e-04 - mse: 3.5303e-04 - val_loss: 4.8894e-04 - val_mse: 9.7787e-04
# Epoch 49/50
# 39/39 [==============================] - ETA: 0s - loss: 1.6542e-04 - mse: 3.3085e-04
# Epoch 49: val_loss did not improve from 0.00046
# 39/39 [==============================] - 1s 17ms/step - loss: 1.6542e-04 - mse: 3.3085e-04 - val_loss: 4.6585e-04 - val_mse: 9.3170e-04
# Epoch 50/50
# 38/39 [============================>.] - ETA: 0s - loss: 1.4799e-04 - mse: 2.9598e-04
# Epoch 50: val_loss improved from 0.00046 to 0.00044, saving model to tmp/ckeckpointer.ckpt
# 39/39 [==============================] - 1s 16ms/step - loss: 1.5389e-04 - mse: 3.0779e-04 - val_loss: 4.4074e-04 - val_mse: 8.8148e-04

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)

# %% [markdown]
# pred: test set - 20(window size)  = 314 - 20 = 294

# %%
pred.shape
# Out:
# (295, 1)

# %% [markdown]
# 예측 데이터 시각화

# %%
plt.figure(figsize=(12, 9))
plt.plot(restore(np.asarray(y_test)[20:]), label='actual')
plt.plot(restore(pred), label='prediction')
plt.legend()
plt.show()

# %%
df_actu = df_org[-len(pred):]
df_actu.tail()
# Out:
#                          index        open        high         low  \
# 1690 2022-05-12 09:00:00+00:00  40263000.0  41178000.0  37000000.0
# 1691 2022-05-13 09:00:00+00:00  39246000.0  41324000.0  38777000.0
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  39000000.0
#
#            close        volume         value
# 1690  39243000.0  23389.063427  9.115180e+11
# 1691  39270000.0  12398.918801  4.983739e+11
# 1692  39967000.0   5512.195620  2.170088e+11
# 1693  40906000.0   4277.655034  1.706726e+11
# 1694  39454000.0   2602.010378  1.035034e+11

# %%
df_actu["pred"] = restore(pred)
df_actu = df_actu[["close", "pred"]]
df_actu.tail()
# Out:
#            close        pred
# 1690  39243000.0  41966316.0
# 1691  39270000.0  40712652.0
# 1692  39967000.0  40115920.0
# 1693  40906000.0  39835660.0
# 1694  39454000.0  40091656.0
